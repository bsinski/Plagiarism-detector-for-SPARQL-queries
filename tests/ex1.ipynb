# %%
import sys  
sys.path.insert(1, '/Users/szymonszmajdzinski/Documents/Studia/Magisterskie/Semestr_2/KG/Plagiarism-detector-for-SPARQL-queries/PDSPARQL')
import calculate_distance

# %% [markdown]
# ## Ex. 1 - Filter expression is splitted into two filter expressions

# %%
query_text1 = """
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX schema: <http://schema.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT ?person ?name WHERE {
  # ?person rdf:type schema:Person ;
  		schema:height ?height;
    	schema:givenName ?name .
  filter(?name="bartek" &&(?height>170 || 180 > ?height))
} 
ORDER BY ?name ?height
"""
query_text2 = """
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX schema: <http://schema.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT ?person ?name WHERE {
  # ?person rdf:type schema:Person ;
  		schema:height ?height;
    	schema:givenName ?name .
  filter(?name="bartek")
  filter(?height>170 || 180 > ?height)
} 
ORDER BY ?name ?height
"""

distance = calculate_distance.compare_queries(query_text1, query_text2, verbose=True)
# Out:
# └──root
#    ├──prefixes
#    │  ├──geo
#    │  │  └──http://www.w3.org/2003/01/geo/wgs84_pos#
#    │  ├──rdf
#    │  │  └──http://www.w3.org/1999/02/22-rdf-syntax-ns#
#    │  └──schema
#    │     └──http://schema.org/
#    └──query
#       ├──order
#       │  ├──?height
#       │  └──?name
#       ├──project
#       │  ├──?name
#       │  └──?person
#       └──filter
#          ├──logic
#          │  └──and
#          ├──expr
#          │  ├──expr
#          │  │  └──?name
#          │  ├──op
#          │  │  └──=
#          │  └──expr
#          │     ├──type
#          │     │  └──Noneee
#          │     └──value
#          │        └──bartek
#          └──expr
#             ├──logic
#             │  └──or
#             ├──expr
#             │  ├──expr
#             │  │  └──?height
#             │  ├──op
#             │  │  └──>
#             │  └──other
#             │     ├──type
#             │     │  └──http://www.w3.org/2001/XMLSchema#integer
#             │     └──value
#             │        └──170
#             └──expr
#                ├──op
#                │  └──>
#                ├──other
#                │  └──?height
#                └──expr
#                   ├──type
#                   │  └──http://www.w3.org/2001/XMLSchema#integer
#                   └──value
#                      └──180
# None
# └──root
#    ├──prefixes
#    │  ├──geo
#    │  │  └──http://www.w3.org/2003/01/geo/wgs84_pos#
#    │  ├──rdf
#    │  │  └──http://www.w3.org/1999/02/22-rdf-syntax-ns#
#    │  └──schema
#    │     └──http://schema.org/
#    └──query
#       ├──order
#       │  ├──?height
#       │  └──?name
#       ├──project
#       │  ├──?name
#       │  └──?person
#       └──filter
#          ├──logic
#          │  └──and
#          ├──expr
#          │  ├──expr
#          │  │  └──?name
#          │  ├──op
#          │  │  └──=
#          │  └──expr
#          │     ├──type
#          │     │  └──Noneee
#          │     └──value
#          │        └──bartek
#          └──expr
#             ├──logic
#             │  └──or
#             ├──expr
#             │  ├──expr
#             │  │  └──?height
#             │  ├──op
#             │  │  └──>
#             │  └──other
#             │     ├──type
#             │     │  └──http://www.w3.org/2001/XMLSchema#integer
#             │     └──value
#             │        └──170
#             └──expr
#                ├──op
#                │  └──>
#                ├──other
#                │  └──?height
#                └──expr
#                   ├──type
#                   │  └──http://www.w3.org/2001/XMLSchema#integer
#                   └──value
#                      └──180
# None
# Distance: 0.0

# %% [markdown]
# ## Expresions in filter are switched

# %%
query_text1 = """
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX schema: <http://schema.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT ?person ?name WHERE {
  # ?person rdf:type schema:Person ;
  		schema:height ?height;
    	schema:givenName ?name .
  filter(?name="bartek")
  filter(?height>170 && 180 > ?height)
} 
ORDER BY ?name ?height
"""

query_text2 = """
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX schema: <http://schema.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT ?person ?name WHERE {
  # ?person rdf:type schema:Person ;
  		schema:height ?height;
    	schema:givenName ?name .
  filter(?name="bartek")
  filter(180 > ?height && ?height>170)
} 
ORDER BY ?name ?height
"""

distance = calculate_distance.compare_queries(query_text1, query_text2, verbose=True)
# Out:
# └──root
#    ├──prefixes
#    │  ├──geo
#    │  │  └──http://www.w3.org/2003/01/geo/wgs84_pos#
#    │  ├──rdf
#    │  │  └──http://www.w3.org/1999/02/22-rdf-syntax-ns#
#    │  └──schema
#    │     └──http://schema.org/
#    └──query
#       ├──order
#       │  ├──?height
#       │  └──?name
#       ├──project
#       │  ├──?name
#       │  └──?person
#       └──filter
#          ├──logic
#          │  └──and
#          ├──expr
#          │  ├──expr
#          │  │  └──?name
#          │  ├──op
#          │  │  └──=
#          │  └──expr
#          │     ├──type
#          │     │  └──Noneee
#          │     └──value
#          │        └──bartek
#          └──expr
#             ├──logic
#             │  └──and
#             ├──expr
#             │  ├──expr
#             │  │  └──?height
#             │  ├──op
#             │  │  └──>
#             │  └──other
#             │     ├──type
#             │     │  └──http://www.w3.org/2001/XMLSchema#integer
#             │     └──value
#             │        └──170
#             └──expr
#                ├──op
#                │  └──>
#                ├──other
#                │  └──?height
#                └──expr
#                   ├──type
#                   │  └──http://www.w3.org/2001/XMLSchema#integer
#                   └──value
#                      └──180
# None
# └──root
#    ├──prefixes
#    │  ├──geo
#    │  │  └──http://www.w3.org/2003/01/geo/wgs84_pos#
#    │  ├──rdf
#    │  │  └──http://www.w3.org/1999/02/22-rdf-syntax-ns#
#    │  └──schema
#    │     └──http://schema.org/
#    └──query
#       ├──order
#       │  ├──?height
#       │  └──?name
#       ├──project
#       │  ├──?name
#       │  └──?person
#       └──filter
#          ├──logic
#          │  └──and
#          ├──expr
#          │  ├──expr
#          │  │  └──?name
#          │  ├──op
#          │  │  └──=
#          │  └──expr
#          │     ├──type
#          │     │  └──Noneee
#          │     └──value
#          │        └──bartek
#          └──expr
#             ├──logic
#             │  └──and
#             ├──expr
#             │  ├──expr
#             │  │  └──?height
#             │  ├──op
#             │  │  └──>
#             │  └──other
#             │     ├──type
#             │     │  └──http://www.w3.org/2001/XMLSchema#integer
#             │     └──value
#             │        └──170
#             └──expr
#                ├──op
#                │  └──>
#                ├──other
#                │  └──?height
#                └──expr
#                   ├──type
#                   │  └──http://www.w3.org/2001/XMLSchema#integer
#                   └──value
#                      └──180
# None
# Distance: 0.0

# %% [markdown]
# # A > B vs B < A

# %%
query_text1 = """
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX schema: <http://schema.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT ?person ?name WHERE {
  # ?person rdf:type schema:Person ;
  		schema:height ?height;
    	schema:givenName ?name .
  filter(?name="bartek")
  filter(?height > 170)
} 
ORDER BY ?name ?height
"""

query_text2 = """
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX schema: <http://schema.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT ?person ?name WHERE {
  # ?person rdf:type schema:Person ;
  		schema:height ?height;
    	schema:givenName ?name .
  filter(?name="bartek")
  filter(180 < ?height)
} 
ORDER BY ?name ?height
"""
distance = calculate_distance.compare_queries(query_text1, query_text2, verbose=True)
# Out:
# └──root
#    ├──prefixes
#    │  ├──geo
#    │  │  └──http://www.w3.org/2003/01/geo/wgs84_pos#
#    │  ├──rdf
#    │  │  └──http://www.w3.org/1999/02/22-rdf-syntax-ns#
#    │  └──schema
#    │     └──http://schema.org/
#    └──query
#       ├──order
#       │  ├──?height
#       │  └──?name
#       ├──project
#       │  ├──?name
#       │  └──?person
#       └──filter
#          ├──logic
#          │  └──and
#          ├──expr
#          │  ├──expr
#          │  │  └──?height
#          │  ├──op
#          │  │  └──>
#          │  └──other
#          │     ├──type
#          │     │  └──http://www.w3.org/2001/XMLSchema#integer
#          │     └──value
#          │        └──170
#          └──expr
#             ├──expr
#             │  └──?name
#             ├──op
#             │  └──=
#             └──expr
#                ├──type
#                │  └──Noneee
#                └──value
#                   └──bartek
# None
# └──root
#    ├──prefixes
#    │  ├──geo
#    │  │  └──http://www.w3.org/2003/01/geo/wgs84_pos#
#    │  ├──rdf
#    │  │  └──http://www.w3.org/1999/02/22-rdf-syntax-ns#
#    │  └──schema
#    │     └──http://schema.org/
#    └──query
#       ├──order
#       │  ├──?height
#       │  └──?name
#       ├──project
#       │  ├──?name
#       │  └──?person
#       └──filter
#          ├──logic
#          │  └──and
#          ├──expr
#          │  ├──op
#          │  │  └──<
#          │  ├──other
#          │  │  └──?height
#          │  └──expr
#          │     ├──type
#          │     │  └──http://www.w3.org/2001/XMLSchema#integer
#          │     └──value
#          │        └──180
#          └──expr
#             ├──expr
#             │  └──?name
#             ├──op
#             │  └──=
#             └──expr
#                ├──type
#                │  └──Noneee
#                └──value
#                   └──bartek
# None
# Distance: 15.0

# %% [markdown]
# ## Queries with changed variable names

# %%
query_text1 = """
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX schema: <http://schema.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT ?person ?name WHERE {
  # ?person rdf:type schema:Person ;
  		schema:height ?height;
    	schema:givenName ?name .
  filter(?name="bartek")
  filter(?height>170 || 180 > ?height)
} 
ORDER BY ?name ?height
"""

query_text2 = """
PREFIX schema: <http://schema.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT ?person ?name WHERE {
  # ?person rdf:type schema:Person ;
    	schema:givenName ?name .
  filter(?name="bartek")
} 
ORDER BY ?name ?height
"""

distance = calculate_distance.compare_queries(query_text1, query_text2)
# Out:
# Distance: 216.0
